# %% [markdown]
# **4.5 Data Consistency Checks**

# %% [markdown]
# Content:
# - #01 Importing libraries
# - #02 Importing dataframes
# - #03 Exercise instructions
# - #04 Exercise task

# %% [markdown]
# #01.Importing libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #02.Importing dataframes

# %%
#creating path shortcut
path = r'C:\Users\EliteMini HX90\OneDrive\Documents\CareerFoundry\Instacart Project Analysis'

# %%
#importing products.csv
df_prods = pd.read_csv(os.path.join(path,'02_Data','01_Original_Data','products.csv'),index_col = False)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#importing orders_wrangled.csv
df_ords = pd.read_csv(os.path.join(path,'02_Data','02_Prepared_Data','orders_wrangled.csv'),index_col=False)

# %%
#check df
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# #4.5 Exercise Instructions

# %%
#get descriptive statistics of df_ords
df_ords.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# ...

# %%
#Create a dataframe
df_test = pd.DataFrame()

# %%
#Create a mixed type column
df_test['mix']=['a','b',1,True]

# %%
#check df
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
#Check for mixed types
for col in df_test.columns.tolist():
  weird = (df_test[[col]].map(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)

#Note - applymap has been flagged as deprecated and replaced by map
# Out:
# mix

# %%
#converting column data type from numeric to string
df_test['mix'] = df_test['mix'].astype('str')

# %%
#finding missing values
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
#creating new dataframe containing only null values from product_name column
df_nan= df_prods[df_prods['product_name'].isnull()==True]
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
#check number of rows and columns of df
df_prods.shape
# Out:
# (49693, 5)

# %%
#Creating new dataframe excluding null values from product_name column
df_prods_clean = df_prods[df_prods['product_name'].isnull()==False]
df_prods_clean.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#check number of rows and columns of df
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
#Finding full duplicates by creating a new subset of df_prods_clean containing only duplicate values
df_dups = df_prods_clean[df_prods_clean.duplicated()]
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
#check number of rows and columns of df
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
#Creating a new dataframe that does not include duplicates
df_prods_clean_no_dups=df_prods_clean.drop_duplicates()
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
#export clean dataset
df_prods_clean_no_dups.to_csv(os.path.join(path,'02_Data','02_Prepared_Data','products_checked.csv'),index=False)

# %% [markdown]
# #4.5 Exercise Task

# %%
#2.Running the df_describe() function on df_ords dataframe to check for unusual data
df_ords.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# ...

# %% [markdown]
# Something does not seem correct with the order_number and days_since_prior_order columns, because the maximum value seem to be lower than the mean, which should not be possible.

# %%
#3.Check for mixed types
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].map(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)

# %% [markdown]
# No mixed-type data seems to have been found.

# %%
#5.1.Checking for missing values
df_ords.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# order_number                   0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
#check number of rows and columns of df
df_ords.shape
# Out:
# (3421083, 6)

# %%
#5.2.Creating new dataframe containing only null values from product_name column
df_ords_nan= df_ords[df_ords['days_since_prior_order'].isnull()==True]
df_ords_nan.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 11   2168274        2             1                   2                 11
# 26   1374495        3             1                   1                 14
# 39   3343014        4             1                   6                 11
# 45   2717275        5             1                   3                 12
#
#     days_since_prior_order
# 0                      NaN
# 11                     NaN
# 26                     NaN
# 39                     NaN
# 45                     NaN

# %%
#check descriptive statistics of df with only null values to identify patterns 
df_ords_nan.describe()
# Out:
#            order_id        user_id  order_number  orders_day_of_week  \
# count  2.062090e+05  206209.000000      206209.0       206209.000000
# mean   1.708462e+06  103105.000000           1.0            2.754118
# std    9.881299e+05   59527.555167           0.0            2.076205
# min    2.000000e+01       1.000000           1.0            0.000000
# 25%    8.507300e+05   51553.000000           1.0            1.000000
# 50%    1.706246e+06  103105.000000           1.0            3.000000
# 75%    2.564292e+06  154657.000000           1.0            5.000000
# max    3.421081e+06  206209.000000           1.0            6.000000
#
#        order_hour_of_day  days_since_prior_order
# count      206209.000000                     0.0
# mean           13.626597                     NaN
# std             4.223769                     NaN
# min             0.000000                     NaN
# 25%            11.000000                     NaN
# ...

# %%
#check for entries with the value 1 in the 'order_number' column to see if they match the count of missing values
df_ords[df_ords['order_number']==1]
# Out:
#          order_id  user_id  order_number  orders_day_of_week  \
# 0         2539329        1             1                   2
# 11        2168274        2             1                   2
# 26        1374495        3             1                   1
# 39        3343014        4             1                   6
# 45        2717275        5             1                   3
# ...           ...      ...           ...                 ...
# 3420930    969311   206205             1                   4
# 3420934   3189322   206206             1                   3
# 3421002   2166133   206207             1                   6
# 3421019   2227043   206208             1                   1
# 3421069   3154581   206209             1                   3
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 11                      11                     NaN
# 26                      14                     NaN
# ...

# %% [markdown]
# The large amount of missing values for the column days_since_prior_order has a logical consistency to it, corresponding in full to rows with order_number 1, ie customers' first order. Logically, we cannot record how many days have passed since the last order when this is the first order.

# %% [markdown]
# #6. For the reason stated above, the missing values are meaningful and should not be deleted. We can also not replace this value with a numerical value like 0, because that would have a different meaning (two orders in the same day). I propose we work with two subsets whenever necessary - first-time orders vs return customers, and otherwise do nothing regarding the missing data and work with the regular df_ords whenever this is irrelevant.

# %%
#Renaming df_ords_nan as df_ords_first_orders to be more descriptive.
df_ords_first_orders = df_ords_nan

# %%
#Creating a new df with only non-first orders
df_ords_return_customers = df_ords[df_ords['days_since_prior_order'].isnull()==False]

# %%
#7.Checking for duplicate values
df_ords_dups = df_ords[df_ords.duplicated()]
df_ords_dups
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# No full duplicated were found in the dataframe.

# %%
#check shape
df_ords.shape
# Out:
# (3421083, 6)

# %%
#9.1.Exporting df_prods

df_prods_clean_no_dups.to_csv(os.path.join(path,'02_Data','02_Prepared_Data','products_checked.csv'),index=False)

# %%
#9.2.Exporting df_ords

df_ords.to_csv(os.path.join(path,'02_Data','02_Prepared_Data','orders_checked.csv'),index=False)
